# %%
from langchain_google_genai import ChatGoogleGenerativeAI
import os
from dotenv import load_dotenv
load_dotenv()



llm = ChatGoogleGenerativeAI(
    model="gemini-flash-lite-latest",
    temperature=0.7,
    google_api_key=os.environ["GOOFLE_API_KEY"]
)

# %%
from langchain_core.prompts import ChatPromptTemplate


my_prompt = ChatPromptTemplate.from_messages(
    [
        ("system","You are a helpful assistant that helps to create and curate posts for a social media platform."),
        ("human","I want to create a post about {topic}")
    ]
)

# %%
chain = my_prompt | llm

# %%
chain.invoke({"topic": "The importance of data privacy in the digital age"})
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'To create an effective post about data privacy, you need to tailor the tone to the platform you are using (e.g., LinkedIn for professional insights, Instagram for visual awareness, or X/Twitter for punchy facts).\n\nHere are three templates you can use:\n\n### Option 1: The "Professional/Thought Leader" Approach (Best for LinkedIn)\n**Headline:** Data is the new currency, but who is spending it?\n\n**Body:** \nWe live in an era where convenience often comes at the cost of our digital footprint. From the apps we download to the websites we browse, our personal data is constantly being harvested. \n\nBut data privacy isn\'t just about "having nothing to hide"—it’s about the fundamental right to control your digital identity. \n\nAs we move toward a more AI-integrated future, protecting our data is no longer just a legal compliance issue; it’s a pillar of digital ethics. \n\n**3 quick ways to take control today:**\n1. Audit your app permissions regularly.\n2. Use a password manager to avoid credential stuffing.\n3. Turn on 2FA (Two-Factor Authentication) everywhere possible.\n\nHow are you prioritizing your digital footprint this year? Let’s discuss in the comments. 👇\n\n#DataPrivacy #CyberSecurity #DigitalEthics #TechTrends #PrivacyMatters\n\n---\n\n### Option 2: The "Punchy/Educational" Approach (Best for X/Twitter)\n**Body:**\n"I have nothing to hide" is the most dangerous phrase in the digital age. \n\nData privacy isn\'t about hiding secrets; it’s about protecting your autonomy. Every data point collected—your location, your habits, your preferences—builds a profile that can be used to influence your choices. \n\nProtecting your data = Protecting your freedom. 🛡️\n\nWhat’s one privacy tip everyone should know? Drop it below! ⬇️\n\n#Privacy #DataProtection #InfoSec #DigitalRights\n\n---\n\n### Option 3: The "Visual/Relatable" Approach (Best for Instagram/Threads)\n**Headline:** Is your "free" app actually costing you more than you think? 📱💸\n\n**Body:** \nEver feel like your phone is listening to you? That’s the power of data tracking. \n\nIn the digital age, if you aren\'t paying for the product, *you* are the product. Your data is being used to predict your behavior, target your ads, and influence your decisions. \n\n**Take back your privacy with these 3 simple steps:**\n✅ Clear your cookies and cache regularly.\n✅ Opt-out of personalized ad tracking in your phone settings.\n✅ Use a privacy-focused browser (like Brave or DuckDuckGo).\n\nKnowledge is power. Don’t let your data be the price of admission to the internet. 🔒\n\n*Save this post so you don’t forget to update your settings!* 📌\n\n#DataPrivacy #TechTips #CyberAwareness #PrivacyTips #DigitalWellness\n\n---\n\n### 💡 3 Tips for Better Engagement:\n1.  **Use an Image:** Posts with a high-quality graphic or a clean, minimalist photo of a lock/digital code perform significantly better than text-only posts.\n2.  **Ask a Question:** Always end with a question to encourage comments. The algorithm loves engagement.\n3.  **Share a Recent News Story:** If there is a major data breach in the news, reference it (without being alarmist) to make your post feel timely and relevant.\n\n**Would you like me to adjust the tone to be more technical, or perhaps more casual?**', 'extras': {'signature': 'EjQKMgEMOdbHZt7cDVmKPpT/kXiOGwMzQBqhM7ZGXw/+gUaVhGJJjC+QJqFjn0MhG2lhz7w3'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019df9e7-3d90-7be0-987f-30d214f54aef-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 35, 'output_tokens': 771, 'total_tokens': 806, 'input_token_details': {'cache_read': 0}})

# %%
my_prompt
# Out:
# ChatPromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a helpful assistant that helps to create and curate posts for a social media platform.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, template='I want to create a post about {topic}'), additional_kwargs={})])
